# %% [markdown]
# # LSTM
#
# TimeSeries or Sequence Data  - 3D tensors of shape(samples, tiuesteps, features

# %%
# Import necessary packages: Keras is obtained from Tensorflow
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.metrics import mse, mae, mape, Accuracy
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the complete data set provided 
data_path = '../data/ucsbdata.csv'
raw_data = pd.read_csv(data_path)
raw_data.head(5)
# Out:
#         Index   R  US10YR   EPS       PER   OPEN   HIGH    LOW  CLOSE  BDIY  \
# 0  1952-01-02 NaN     NaN  2.44  9.754098  23.80  23.80  23.80  23.80   NaN
# 1  1952-01-03 NaN     NaN  2.44  9.786885  23.88  23.88  23.88  23.88   NaN
# 2  1952-01-04 NaN     NaN  2.44  9.803279  23.92  23.92  23.92  23.92   NaN
# 3  1952-01-07 NaN     NaN  2.44  9.799180  23.91  23.91  23.91  23.91   NaN
# 4  1952-01-08 NaN     NaN  2.44  9.762295  23.82  23.82  23.82  23.82   NaN
#
#    ...  MYSTERYVAR3  TOM  HULBERTSENTIMENT  BUBBLE  CASH  DEBT  DIVIDEND  \
# 0  ...          NaN    0               NaN     NaN   NaN   NaN       NaN
# 1  ...          NaN    0               NaN     NaN   NaN   NaN       NaN
# 2  ...          NaN    0               NaN     NaN   NaN   NaN       NaN
# 3  ...          NaN    0               NaN     NaN   NaN   NaN       NaN
# 4  ...          NaN    0               NaN     NaN   NaN   NaN       NaN
#
#    RETURN  STOCKS  WAR
# 0     NaN     NaN  NaN
# 1     NaN     NaN  NaN
# 2     NaN     NaN  NaN
# 3     NaN     NaN  NaN
# 4     NaN     NaN  NaN
#
# [5 rows x 68 columns]

# %%
# From the EDA will work with complete stock data after the market crash of 2008
initial_start = '2008-08-30'
data = raw_data.loc[raw_data.Index > initial_start]
data.head(5)
# Out:
#             Index         R  US10YR    EPS        PER     OPEN     HIGH  \
# 14262  2008-09-02 -0.000925  3.7326  49.78  25.664524  1287.83  1303.04
# 14263  2008-09-03 -0.021012  3.6990  49.78  25.612294  1276.61  1280.60
# 14264  2008-09-04  0.003075  3.6227  49.76  24.855908  1271.80  1271.80
# 14265  2008-09-05  0.020380  3.6986  49.76  24.966037  1233.21  1244.94
# 14266  2008-09-08 -0.021026  3.6743  49.75  25.483216  1249.50  1274.42
#
#            LOW    CLOSE    BDIY  ...  MYSTERYVAR3  TOM  HULBERTSENTIMENT  \
# 14262  1272.20  1277.58  6466.0  ...    12.805545    1              11.7
# 14263  1265.59  1274.98  6146.0  ...    12.747167    0              -2.1
# 14264  1232.83  1236.83  5874.0  ...    12.790740    0              -2.1
# 14265  1217.23  1242.31  5663.0  ...    12.944056    0              -2.1
# 14266  1247.12  1267.79  5492.0  ...    12.891218    0              -9.0
#
#            BUBBLE       CASH       DEBT   DIVIDEND     RETURN     STOCKS  \
# 14262  102.145351  80.224149  52.613405  42.572673  20.866767  32.085132
# 14263   87.724831  76.736143  59.870426  37.019715  22.681269  35.522825
# 14264   96.136801  81.386818  62.591809  45.040654  21.169184  36.668722
# 14265   99.741931  81.386818  61.684682  42.572673  20.866767  38.960517
# 14266   98.540221  80.224149  54.427660  45.040654  20.564351  38.960517
#
#              WAR
# 14262  43.392387
# 14263  40.981699
# 14264  43.995059
# 14265  44.597731
# 14266  47.611092
#
# [5 rows x 68 columns]

# %%
# Look at the data type for each coloum
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2601 entries, 14262 to 16862
# Data columns (total 68 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index             2601 non-null   object
#  1   R                 2601 non-null   float64
#  2   US10YR            2601 non-null   float64
#  3   EPS               2601 non-null   float64
#  4   PER               2601 non-null   float64
#  5   OPEN              2601 non-null   float64
#  6   HIGH              2601 non-null   float64
#  7   LOW               2601 non-null   float64
#  8   CLOSE             2601 non-null   float64
#  9   BDIY              2601 non-null   float64
#  10  VIX               2601 non-null   float64
#  11  PCR               2601 non-null   float64
#  12  MVOLE             2601 non-null   float64
#  13  DXY               2601 non-null   float64
#  14  ASP               2601 non-null   float64
#  15  ADVDECL           2601 non-null   float64
#  16  FEDFUNDS          2601 non-null   float64
#  17  NYSEADV           2601 non-null   float64
#  18  IC                2601 non-null   float64
#  19  BAA               2601 non-null   float64
#  20  NOS               2601 non-null   float64
#  21  BER               2601 non-null   float64
#  22  DVY               2601 non-null   float64
#  23  PTB               2601 non-null   float64
#  24  AAA               2601 non-null   float64
#  25  SI                2601 non-null   float64
#  26  URR               2601 non-null   int64
#  27  FOMC              2601 non-null   int64
#  28  PPIR              2601 non-null   int64
#  29  RV                2601 non-null   float64
#  30  LOAN              2601 non-null   float64
#  31  VVIX              2601 non-null   float64
#  32  NAPMNEWO          2601 non-null   float64
#  33  NAPMPRIC          2601 non-null   float64
#  34  NAPMPMI           2601 non-null   float64
#  35  US3M              2601 non-null   float64
#  36  DEL               2601 non-null   float64
#  37  BBY               2601 non-null   float64
#  38  HTIME             2601 non-null   float64
#  39  LTIME             2601 non-null   float64
#  40  TYVIX             2601 non-null   float64
#  41  CRP               2601 non-null   float64
#  42  TERM              2601 non-null   float64
#  43  UR                2601 non-null   float64
#  44  INDPRO            2601 non-null   float64
#  45  HS                2601 non-null   float64
#  46  VRP               2601 non-null   float64
#  47  CAPE              2601 non-null   float64
#  48  CATY              2601 non-null   float64
#  49  INF               2601 non-null   float64
#  50  SIM               2601 non-null   int64
#  51  RELINF            2601 non-null   float64
#  52  SENTIMENT1        2601 non-null   float64
#  53  SENTIMENT2        2601 non-null   float64
#  54  SENTIMENT3        2601 non-null   float64
#  55  SENTIMENT4        2601 non-null   float64
#  56  MYSTERYVAR1       2601 non-null   float64
#  57  MYSTERYVAR2       2601 non-null   float64
#  58  MYSTERYVAR3       2601 non-null   float64
#  59  TOM               2601 non-null   int64
#  60  HULBERTSENTIMENT  2601 non-null   float64
#  61  BUBBLE            2601 non-null   float64
#  62  CASH              2601 non-null   float64
#  63  DEBT              2601 non-null   float64
#  64  DIVIDEND          2601 non-null   float64
#  65  RETURN            2601 non-null   float64
#  66  STOCKS            2601 non-null   float64
#  67  WAR               2601 non-null   float64
# dtypes: float64(62), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
# Convert Int values to float
non_floats = ['URR', 'FOMC', 'PPIR', 'SIM', 'HULBERTSENTIMENT', 'TOM']
for i in non_floats:
    data[i] = data[i].astype(float)

# %%
# Recheck datatype
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2601 entries, 14262 to 16862
# Data columns (total 68 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index             2601 non-null   object
#  1   R                 2601 non-null   float64
#  2   US10YR            2601 non-null   float64
#  3   EPS               2601 non-null   float64
#  4   PER               2601 non-null   float64
#  5   OPEN              2601 non-null   float64
#  6   HIGH              2601 non-null   float64
#  7   LOW               2601 non-null   float64
#  8   CLOSE             2601 non-null   float64
#  9   BDIY              2601 non-null   float64
#  10  VIX               2601 non-null   float64
#  11  PCR               2601 non-null   float64
#  12  MVOLE             2601 non-null   float64
#  13  DXY               2601 non-null   float64
#  14  ASP               2601 non-null   float64
#  15  ADVDECL           2601 non-null   float64
#  16  FEDFUNDS          2601 non-null   float64
#  17  NYSEADV           2601 non-null   float64
#  18  IC                2601 non-null   float64
#  19  BAA               2601 non-null   float64
#  20  NOS               2601 non-null   float64
#  21  BER               2601 non-null   float64
#  22  DVY               2601 non-null   float64
#  23  PTB               2601 non-null   float64
#  24  AAA               2601 non-null   float64
#  25  SI                2601 non-null   float64
#  26  URR               2601 non-null   float64
#  27  FOMC              2601 non-null   float64
#  28  PPIR              2601 non-null   float64
#  29  RV                2601 non-null   float64
#  30  LOAN              2601 non-null   float64
#  31  VVIX              2601 non-null   float64
#  32  NAPMNEWO          2601 non-null   float64
#  33  NAPMPRIC          2601 non-null   float64
#  34  NAPMPMI           2601 non-null   float64
#  35  US3M              2601 non-null   float64
#  36  DEL               2601 non-null   float64
#  37  BBY               2601 non-null   float64
#  38  HTIME             2601 non-null   float64
#  39  LTIME             2601 non-null   float64
#  40  TYVIX             2601 non-null   float64
#  41  CRP               2601 non-null   float64
#  42  TERM              2601 non-null   float64
#  43  UR                2601 non-null   float64
#  44  INDPRO            2601 non-null   float64
#  45  HS                2601 non-null   float64
#  46  VRP               2601 non-null   float64
#  47  CAPE              2601 non-null   float64
#  48  CATY              2601 non-null   float64
#  49  INF               2601 non-null   float64
#  50  SIM               2601 non-null   float64
#  51  RELINF            2601 non-null   float64
#  52  SENTIMENT1        2601 non-null   float64
#  53  SENTIMENT2        2601 non-null   float64
#  54  SENTIMENT3        2601 non-null   float64
#  55  SENTIMENT4        2601 non-null   float64
#  56  MYSTERYVAR1       2601 non-null   float64
#  57  MYSTERYVAR2       2601 non-null   float64
#  58  MYSTERYVAR3       2601 non-null   float64
#  59  TOM               2601 non-null   float64
#  60  HULBERTSENTIMENT  2601 non-null   float64
#  61  BUBBLE            2601 non-null   float64
#  62  CASH              2601 non-null   float64
#  63  DEBT              2601 non-null   float64
#  64  DIVIDEND          2601 non-null   float64
#  65  RETURN            2601 non-null   float64
#  66  STOCKS            2601 non-null   float64
#  67  WAR               2601 non-null   float64
# dtypes: float64(67), object(1)
# memory usage: 1.4+ MB

# %%
# Convert the string datatype to a datetime
index_datetime = pd.to_datetime(data['Index']).values
data['Index'] = index_datetime
print(type(data['Index'].values[0]))
# Replace current index with data index
data.set_index('Index', inplace = True)
data.head(5)
# Out:
# <class 'numpy.datetime64'>
#                    R  US10YR    EPS        PER     OPEN     HIGH      LOW  \
# Index
# 2008-09-02 -0.000925  3.7326  49.78  25.664524  1287.83  1303.04  1272.20
# 2008-09-03 -0.021012  3.6990  49.78  25.612294  1276.61  1280.60  1265.59
# 2008-09-04  0.003075  3.6227  49.76  24.855908  1271.80  1271.80  1232.83
# 2008-09-05  0.020380  3.6986  49.76  24.966037  1233.21  1244.94  1217.23
# 2008-09-08 -0.021026  3.6743  49.75  25.483216  1249.50  1274.42  1247.12
#
#               CLOSE    BDIY    VIX  ...  MYSTERYVAR3  TOM  HULBERTSENTIMENT  \
# Index                               ...
# 2008-09-02  1277.58  6466.0  21.99  ...    12.805545  1.0              11.7
# 2008-09-03  1274.98  6146.0  21.43  ...    12.747167  0.0              -2.1
# 2008-09-04  1236.83  5874.0  24.03  ...    12.790740  0.0              -2.1
# 2008-09-05  1242.31  5663.0  23.06  ...    12.944056  0.0              -2.1
# 2008-09-08  1267.79  5492.0  22.64  ...    12.891218  0.0              -9.0
#
#                 BUBBLE       CASH       DEBT   DIVIDEND     RETURN     STOCKS  \
# Index
# 2008-09-02  102.145351  80.224149  52.613405  42.572673  20.866767  32.085132
# 2008-09-03   87.724831  76.736143  59.870426  37.019715  22.681269  35.522825
# 2008-09-04   96.136801  81.386818  62.591809  45.040654  21.169184  36.668722
# 2008-09-05   99.741931  81.386818  61.684682  42.572673  20.866767  38.960517
# 2008-09-08   98.540221  80.224149  54.427660  45.040654  20.564351  38.960517
#
#                   WAR
# Index
# 2008-09-02  43.392387
# 2008-09-03  40.981699
# 2008-09-04  43.995059
# 2008-09-05  44.597731
# 2008-09-08  47.611092
#
# [5 rows x 67 columns]

# %%
# Seperate features from returns 
sp_returns = data['R'].values
features = data.iloc[:,1:].values

# Split data with 80% train data, 20% test
test_percent = 0.1
data_train, data_test, train_labels, test_labels = train_test_split(features,
                                                                    sp_returns,
                                                                    test_size = test_percent, 
                                                                    random_state = 0,
                                                                   shuffle = False)

print(len(features))
print(len(sp_returns))
print("Train data shape", data_train.shape)
print("Test data shape", data_test.shape)
# Out:
# 2601
# 2601
# Train data shape (2340, 66)
# Test data shape (261, 66)

# %%
# Initiate standard scaler
sc = StandardScaler()
# Normalize the data with training data
data_train = sc.fit_transform(data_train)
data_test = sc.transform(data_test)
# check to see if data was correctly normalized
print(np.mean(data_train))
print(np.mean(data_test))
print(np.std(data_train))
print(np.std(data_test))
print(data_train.shape)
print(data_test.shape)
# Out:
# 1.0909343013690426e-15
# 0.4903356457040522
# 1.0000000000000002
# 1.527291113862471
# (2340, 66)
# (261, 66)

# %%
# Parameters for transforming to supervised data
lookback = 3 # How many timesteps back; 5 i.e a week
step = 1 # The period at which we sample data i.e 1 day
batch_size =  60 #number of samples per batch i.e a month

# %%
# Train, validatopm, Test data generator
train_generator =  TimeseriesGenerator(data_train[:2000], train_labels[:2000], length=lookback,
                                      batch_size=batch_size, sampling_rate=step)

validation_generator = TimeseriesGenerator(data_train[2001:], train_labels[2001:], length=lookback,
                                          batch_size=batch_size, sampling_rate=step)

test_generator = TimeseriesGenerator(data_test, test_labels, length=lookback,
                                    batch_size=batch_size, sampling_rate=step)

# %%
# Create and test model
def build_model():
    model = Sequential()
    model.add(LSTM(128,
                  activation='relu',
                  input_shape = (lookback, 66), return_sequences=True))
    model.add(Dropout(0.25))
    model.add(LSTM(64,
                  activation='relu',
                  input_shape = (lookback, 66)))
    model.add(Dense(1))
    model.compile(optimizer='ADAM', loss = 'mean_squared_error')
    return model

# %%
model = build_model()
history = model.fit(train_generator,validation_data = validation_generator,epochs=40)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 34 steps, validate for 6 steps
# Epoch 1/40
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 2/40
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0011 - val_loss: 5.8122e-04
# Epoch 3/40
# 34/34 [==============================] - 1s 15ms/step - loss: 4.7234e-04 - val_loss: 4.0407e-04
# Epoch 4/40
# 34/34 [==============================] - 1s 15ms/step - loss: 2.3973e-04 - val_loss: 2.9192e-04
# Epoch 5/40
# 34/34 [==============================] - 0s 15ms/step - loss: 1.9695e-04 - val_loss: 2.5527e-04
# Epoch 6/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.6870e-04 - val_loss: 1.8000e-04
# Epoch 7/40
# 34/34 [==============================] - 0s 15ms/step - loss: 1.5205e-04 - val_loss: 1.6161e-04
# Epoch 8/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.4512e-04 - val_loss: 1.5665e-04
# Epoch 9/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.4291e-04 - val_loss: 1.6723e-04
# Epoch 10/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.3497e-04 - val_loss: 1.2727e-04
# Epoch 11/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.2837e-04 - val_loss: 1.2537e-04
# Epoch 12/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.2574e-04 - val_loss: 1.1574e-04
# Epoch 13/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1899e-04 - val_loss: 2.0059e-04
# Epoch 14/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1312e-04 - val_loss: 1.2205e-04
# Epoch 15/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1457e-04 - val_loss: 1.0910e-04
# Epoch 16/40
# 34/34 [==============================] - 0s 15ms/step - loss: 1.1120e-04 - val_loss: 1.3572e-04
# Epoch 17/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.0799e-04 - val_loss: 1.2328e-04
# Epoch 18/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1299e-04 - val_loss: 9.0103e-05
# Epoch 19/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.0606e-04 - val_loss: 8.5788e-05
# Epoch 20/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.0370e-04 - val_loss: 1.0182e-04
# Epoch 21/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.0481e-04 - val_loss: 1.0294e-04
# Epoch 22/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.9133e-05 - val_loss: 1.2320e-04
# Epoch 23/40
# 34/34 [==============================] - 1s 15ms/step - loss: 1.0148e-04 - val_loss: 9.1572e-05
# Epoch 24/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.6320e-05 - val_loss: 1.7497e-04
# Epoch 25/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.4898e-05 - val_loss: 7.9595e-05
# Epoch 26/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.4577e-05 - val_loss: 8.2926e-05
# Epoch 27/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.5156e-05 - val_loss: 7.9902e-05
# Epoch 28/40
# 34/34 [==============================] - 0s 15ms/step - loss: 9.3965e-05 - val_loss: 7.5176e-05
# Epoch 29/40
# 34/34 [==============================] - 1s 16ms/step - loss: 9.4666e-05 - val_loss: 8.5774e-05
# Epoch 30/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.1963e-05 - val_loss: 7.4270e-05
# Epoch 31/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.9547e-05 - val_loss: 1.1516e-04
# Epoch 32/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.8674e-05 - val_loss: 8.7656e-05
# Epoch 33/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.6877e-05 - val_loss: 8.7693e-05
# Epoch 34/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.6135e-05 - val_loss: 7.3855e-05
# Epoch 35/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.8118e-05 - val_loss: 9.4883e-05
# Epoch 36/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.3751e-05 - val_loss: 6.5069e-05
# Epoch 37/40
# 34/34 [==============================] - 1s 15ms/step - loss: 9.0609e-05 - val_loss: 1.1811e-04
# Epoch 38/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.7205e-05 - val_loss: 8.6022e-05
# Epoch 39/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.5126e-05 - val_loss: 8.7900e-05
# Epoch 40/40
# 34/34 [==============================] - 1s 15ms/step - loss: 8.3435e-05 - val_loss: 7.5740e-05

# %%
plt.figure(figsize=(15,10))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
predictions = model.predict(test_generator)

# %%
plt.figure(figsize=(15,10))
plt.plot(predictions, label='predictions')
plt.plot(test_labels, label='labels')
plt.legend()
